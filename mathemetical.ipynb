# %%
import array as arr
def mean():
 a = arr.array('i')
 b = int(input("enter a digit"))
 a.append(b)
 c = int(input("enter a digigt"))
 a.append(c)
 d = int(input("enter a digigt"))
 a.append(d)
 e = int(input("enter a digigt"))
 a.append(e)
 f = int(input("enter a digigt"))
 a.append(f)
 sum = a[0] + a[1] + a[2] + a[3] + a[4]
 mean = sum // len(a)
 print(f"the mean of this thing is {mean}")
 mean()




def median():
  aa = arr.array('i' , [4 , 2  , 6 , 7 , 8 , 9])
  aa =sorted(aa)
  if len(aa) % 2 == 0:
    sum = (aa[len(aa) //2] + aa[len(aa)//2+1])
    median = sum//2
    print(f"the median is {median}")
  else:
    index = len(aa) // 2
    median = aa[index]
    print("the median of your thing is " , median)
median()

def maxenmin():
  aa = arr.array('i' , [4 , 2  , 6 , 7 , 8 , 9])
  aa = sorted(aa)
  print(f"the smallest number is {aa[0]}")
  print(f"the biggest number is {aa[-1]}")
maxenmin()
# Out:
# 7
# the smallest number is 2
# the smallest number is 9
